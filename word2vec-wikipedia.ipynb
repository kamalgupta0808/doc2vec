# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Author: Pan Yang (panyangnlp@gmail.com)
# Copyrigh 2017

from __future__ import print_function

import logging
import os.path
import six
import sys

from gensim.corpora import WikiCorpus

if __name__ == '__main__':
    program = os.path.basename(sys.argv[0])
    logger = logging.getLogger(program)

    logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
    logging.root.setLevel(level=logging.INFO)
    logger.info("running %s" % ' '.join(sys.argv))

    # check and process input arguments
    if len(sys.argv) != 3:
        print("Using: python process_wiki.py enwiki.xxx.xml.bz2 wiki.en.text")
        sys.exit(1)
    inp, outp = sys.argv[1:3]
    space = " "
    i = 0

    output = open(outp, 'w')
    wiki = WikiCorpus('/home/kamal/Downloads/simplewiki-latest-pages-articles.xml.bz2', lemmatize=False, dictionary={})
    for text in wiki.get_texts():
        if six.PY3:
            output.write(bytes(' '.join(text), 'utf-8').decode('utf-8') + '\n')
        #   ###another method###
        #    output.write(
        #            space.join(map(lambda x:x.decode("utf-8"), text)) + '\n')
        else:
            output.write(space.join(text) + "\n")
        i = i + 1
        if (i % 10000 == 0):
            logger.info("Saved " + str(i) + " articles")

    output.close()
logger.info("Finished Saved " + str(i) + " articles")
# Out:
# 2018-04-15 13:34:39,670: INFO: running /home/kamal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py -f /run/user/1000/jupyter/kernel-38ddf288-0ad8-4986-9ee7-e11ef648aefd.json
# 2018-04-15 13:34:39,879: INFO: adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-15 13:34:58,072: INFO: adding document #10000 to Dictionary(146391 unique tokens: ['abdicated', 'abdicates', 'abraham', 'additionally', 'adolf']...)
# 2018-04-15 13:35:12,486: INFO: adding document #20000 to Dictionary(208246 unique tokens: ['abdicated', 'abdicates', 'abraham', 'additionally', 'adolf']...)
# 2018-04-15 13:35:29,448: INFO: adding document #30000 to Dictionary(263758 unique tokens: ['abdicated', 'abdicates', 'abraham', 'additionally', 'adolf']...)
# 2018-04-15 13:35:48,584: INFO: adding document #40000 to Dictionary(305561 unique tokens: ['abdicated', 'abdicates', 'abraham', 'additionally', 'adolf']...)
# ...

# %%
print (outp)
# Out:
# /run/user/1000/jupyter/kernel-38ddf288-0ad8-4986-9ee7-e11ef648aefd.json

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Author: Pan Yang (panyangnlp@gmail.com)
# Copyright 2017

from __future__ import print_function

import logging
import os
import sys
import multiprocessing

from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

if __name__ == '__main__':
    program = os.path.basename(sys.argv[0])
    logger = logging.getLogger(program)

    logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
    logging.root.setLevel(level=logging.INFO)
    logger.info("running %s" % ' '.join(sys.argv))

    # check and process input arguments
    if len(sys.argv) < 4:
        print("Useing: python train_word2vec_model.py input_text "
              "output_gensim_model output_word_vector")
        
    print(sys.argv[1:4])
    inp, outp1 = sys.argv[1:4]

    model = Word2Vec(LineSentence('/home/kamal/Downloads/simplewiki-latest-pages-articles.xml.bz2'), size=200, window=5, min_count=5,workers=multiprocessing.cpu_count())

    model.save('/home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin')
model.wv.save_word2vec_format('/home/kamal/ML/Context_similarity/word2vec-wikipedia/word2vec_wikipedia.txt', binary=False)
# Out:
# 2018-04-15 16:16:55,242: INFO: running /home/kamal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py -f /run/user/1000/jupyter/kernel-38ddf288-0ad8-4986-9ee7-e11ef648aefd.json
# 2018-04-15 16:16:55,243: INFO: collecting all words and their counts
# 2018-04-15 16:16:55,272: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-04-15 16:16:55,442: INFO: PROGRESS: at sentence #10000, processed 118411 words, keeping 32192 word types
# Useing: python train_word2vec_model.py input_text output_gensim_model output_word_vector
# ['-f', '/run/user/1000/jupyter/kernel-38ddf288-0ad8-4986-9ee7-e11ef648aefd.json']
# 2018-04-15 16:16:55,597: INFO: PROGRESS: at sentence #20000, processed 225576 words, keeping 55054 word types
# 2018-04-15 16:16:55,761: INFO: PROGRESS: at sentence #30000, processed 351556 words, keeping 76893 word types
# 2018-04-15 16:16:55,897: INFO: PROGRESS: at sentence #40000, processed 435333 words, keeping 93363 word types
# ...

# %%
import gensim
model = gensim.models.Word2Vec.load("/home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin")
# Out:
# 2018-04-15 16:39:20,183: INFO: loading Word2Vec object from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin
# 2018-04-15 16:39:21,772: INFO: loading wv recursively from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin.wv.* with mmap=None
# 2018-04-15 16:39:21,773: INFO: loading vectors from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin.wv.vectors.npy with mmap=None
# 2018-04-15 16:39:26,300: INFO: setting ignored attribute vectors_norm to None
# 2018-04-15 16:39:26,302: INFO: loading vocabulary recursively from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin.vocabulary.* with mmap=None
# 2018-04-15 16:39:26,303: INFO: loading trainables recursively from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin.trainables.* with mmap=None
# 2018-04-15 16:39:26,305: INFO: loading syn1neg from /home/kamal/ML/Context_similarity/word2vec-wikipedia/model.bin.trainables.syn1neg.npy with mmap=None
# ...

# %%
model.most_similar("currency")
# Out:
# /home/kamal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('currency,', 0.6568357944488525),
#  ('ISO', 0.641348123550415),
#  ('numbering', 0.617510199546814),
#  ('prefix', 0.6140391826629639),
#  ('membership', 0.613814651966095),
#  ('domain', 0.6097549200057983),
#  ('[[currency]]', 0.6058094501495361),
#  ('usage', 0.6025542616844177),
#  ('unit', 0.6011337637901306),
#  ('currency.', 0.5995355844497681)]

# %%
model.similarity("man", "woman")
# Out:
# /home/kamal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.7838815102010996
